# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import json
import string
import time
import math
import random
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

from nltk.translate.bleu_score import SmoothingFunction, sentence_bleu

# %%
# Seq2Seq model hyperparameter setting
SOS_token = 0
EOS_token = 1
vocab_num = 28
MAX_LENGTH = 21
plot_steps = 5

# Mode Setting
train_mode = True
display_mode = False
show_predict_text = False

data_root = Path('data')
model_root = Path('model')
image_root = Path('image')
log_root = Path('log')
model_name = "lstm_model-sgd"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, emb_dim, hid_dim, n_layers, dropout):
        super().__init__()
        self.hid_dim = hid_dim
        self.n_layers = n_layers
        self.embedding = nn.Embedding(input_dim, emb_dim)
        self.rnn = nn.LSTM(emb_dim, hid_dim, n_layers, dropout = dropout)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, src):
        embedded = self.dropout(self.embedding(src))
        outputs, (hidden, cell) = self.rnn(embedded)
        return hidden, cell

# %%
class Decoder(nn.Module):
    def __init__(self, output_dim, emb_dim, hid_dim, n_layers, dropout):
        super().__init__()
        self.output_dim = output_dim
        self.hid_dim = hid_dim
        self.n_layers = n_layers
        self.embedding = nn.Embedding(output_dim, emb_dim)
        self.rnn = nn.LSTM(emb_dim, hid_dim, n_layers, dropout = dropout)
        self.fc_out = nn.Linear(hid_dim, output_dim)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, input, hidden, cell):
        input = input.unsqueeze(0)
        embedded = self.dropout(self.embedding(input))
        output, (hidden, cell) = self.rnn(embedded, (hidden, cell))
        prediction = self.fc_out(output.squeeze(0))
        return prediction, hidden, cell

# %%
class Seq2Seq(nn.Module):
	def __init__(self, encoder, decoder, device):
		super().__init__()
		self.encoder = encoder
		self.decoder = decoder
		self.device = device
		
		assert encoder.hid_dim == decoder.hid_dim, \
			"Hidden dimensions of encoder and decoder must be equal!"
		assert encoder.n_layers == decoder.n_layers, \
			"Encoder and decoder must have equal number of layers!"
		
	def forward(self, src, trg, teacher_forcing_ratio = 0.5):
		batch_size = trg.shape[1]
		trg_len = trg.shape[0]
		trg_vocab_size = self.decoder.output_dim
		outputs = torch.zeros(trg_len, batch_size, trg_vocab_size).to(self.device)
		hidden, cell = self.encoder(src)
		input = trg[0,:]
		for t in range(1, trg_len):
			output, hidden, cell = self.decoder(input, hidden, cell)
			outputs[t] = output
			teacher_force = random.random() < teacher_forcing_ratio
			top1 = output.argmax(1) 
			if torch.equal(top1, torch.ones_like(top1)):
				break
			input = trg[t] if teacher_force else top1

		return outputs

# %%
# context switch process
def ids2text(index_list):
	embed = ["<SOS>", "<EOS>"] + list("abcdefghijklmnopqrstuvwxyz")
	text = ""
	for id in index_list:
		if id == EOS_token:
			break
		if id == SOS_token:
			continue
		text += embed[id]
	return text

def tensor2text(output, target, batch_size):
	pred = torch.swapaxes(output, 0, 1)
	trg = torch.swapaxes(target, 0, 1)
	pred_texts = []
	trg_texts = []

	for j in range(batch_size):
		_, topi = pred[j].topk(1)
		pred_text = ids2text(topi.squeeze())
		trg_text = ids2text(trg[j])
		pred_texts.append(pred_text)
		trg_texts.append(trg_text)

	return pred_texts, trg_texts

# My data loader function
def my_data_loader(data_file, batch_size=4):
	# character embedding
	embed = dict(zip(string.ascii_lowercase, range(2, 28)))

	# data read from json file
	with open(data_file) as f:
		data = json.load(f)

	# mapping text from a-z to 1-27, 0 for SOS, 28 for EOS, 28 for PAD shared with EOS
	input_tensors = []
	target_tensors = []
	batch_pairs = []
	for item in data:
		input_ids = []

		# {'train': [A, B], 'target': [a]} => [A, a], [B, a]
		target_ids = [SOS_token] + [embed[c] for c in item["target"]] + [EOS_token]*(MAX_LENGTH-len(item["target"])-1)
		target = torch.tensor(target_ids).view(21, 1)

		for text in item['input']: # multiple words
			input_ids= [SOS_token] + [embed[c] for c in text] + [EOS_token]*(MAX_LENGTH-len(text)-1)
			input_tensors.append(torch.tensor(input_ids).view(21, 1))
			target_tensors.append(target)

	for i in range(0, len(input_tensors)-batch_size, batch_size):
		if i+batch_size > len(input_tensors):
			break
		input_tensor = torch.cat(input_tensors[i:i+batch_size], dim=1)
		target_tensor = torch.cat(target_tensors[i:i+batch_size], dim=1)
		batch_pairs.append((input_tensor, target_tensor))

	return batch_pairs

# Visualize of training progress
def train_visualize(train, valid, datatype="Loss"):
	plt.plot(train, label='Train')
	plt.plot(valid, label='Valid')

	plt.xlabel('Epochs')
	plt.ylabel(datatype)
	plt.title(f'Seq2Seq training {datatype}')
	plt.legend()
	plt.savefig(image_root / f'seq2seq_{datatype}-{model_name}.jpg')
	plt.clf()
	if display_mode:
		plt.show()

#compute BLEU-4 score
def compute_bleu(output, reference):
    cc = SmoothingFunction()
    if len(reference) == 3:
        weights = (0.33,0.33,0.33)
    else:
        weights = (0.25,0.25,0.25,0.25)
    return sentence_bleu([reference], output,weights=weights,smoothing_function=cc.method1)

# %%
# Model configuration
INPUT_DIM = vocab_num
OUTPUT_DIM = vocab_num
ENC_EMB_DIM = 256
DEC_EMB_DIM = 256
HID_DIM = 512
N_LAYERS = 2
ENC_DROPOUT = 0.5
DEC_DROPOUT = 0.5
BATCH_SIZE = 64
TEST_BATCH_SIZE = 1

# Model Training parameters
N_EPOCHS = 500
CLIP = 1

# Initialize model, encoder, and decoder
hidden_size = 256
enc = Encoder(INPUT_DIM, ENC_EMB_DIM, HID_DIM, N_LAYERS, ENC_DROPOUT)
dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, HID_DIM, N_LAYERS, DEC_DROPOUT)
model = Seq2Seq(enc, dec, device).to(device)

# Define optimizer and criterion
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
criterion = nn.CrossEntropyLoss()

# %%
# Prepare data
train_iterator = my_data_loader(data_root / 'train.json', batch_size=BATCH_SIZE)
valid_iterator = my_data_loader(data_root / 'test.json', batch_size=TEST_BATCH_SIZE)
test_iterator = my_data_loader(data_root / 'new_test.json', batch_size=TEST_BATCH_SIZE)

# %%
# Train & Validate function
def train(model, iterator, optimizer, criterion, clip, batch_size):
    
	model.train()

	epoch_loss = 0
	epoch_bleus = 0

	for i, batch in enumerate(iterator):
		
		src = batch[0].to(device)
		trg = batch[1].to(device)
		
		optimizer.zero_grad()
		
		output = model(src, trg)
		
		#trg = [trg len, batch size]
		#output = [trg len, batch size, output dim]
		pred_text, trg_text = tensor2text(output, trg, batch_size)
		
		output_dim = output.shape[-1]
		
		output = output[1:].view(-1, output_dim)
		trg = trg[1:].view(-1)
		
		#trg = [(trg len - 1) * batch size]
		#output = [(trg len - 1) * batch size, output dim]
		

		loss = criterion(output, trg)
		
		loss.backward()
		
		torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
		
		optimizer.step()
		
		epoch_loss += loss.item()
		for p, t in zip(pred_text, trg_text):
			epoch_bleus += compute_bleu(p, t)
			
	return epoch_loss / len(iterator), epoch_bleus / (len(iterator) * batch_size)

def evaluate(model, iterator, criterion, batch_size, split='test', islog=False):

	model.eval()

	epoch_loss = 0
	epoch_bleus = 0
	acc = 0

	if islog:
		f = open(log_root / f'{split}-{model_name}_log.txt', 'w')

	with torch.no_grad():

		for i, batch in enumerate(iterator):

			src = batch[0].to(device)
			trg = batch[1].to(device)

			output = model(src, trg, 0) #turn off teacher forcing

			#trg = [trg len, batch size]
			#output = [trg len, batch size, output dim]
			pred_text, trg_text = tensor2text(output, trg, batch_size)
			pred_text, src_text = tensor2text(output, src, TEST_BATCH_SIZE)

			output_dim = output.shape[-1]
			
			output = output[1:].view(-1, output_dim)
			trg = trg[1:].view(-1)

			#trg = [(trg len - 1) * batch size]
			#output = [(trg len - 1) * batch size, output dim]

			loss = criterion(output, trg)
			
			epoch_loss += loss.item()
			for p, t, s in zip(pred_text, trg_text, src_text):
				if islog:
					f.write("="*20+"\n")
					f.write(f"input:  {s}\n")
					f.write(f"target: {t}\n")
					f.write(f"pred:   {p}\n")
				acc += compute_bleu(p, t) == 1
				epoch_bleus += compute_bleu(p, t)
	
	if islog:
		f.write(f"Bleu-4 score: {epoch_bleus / (len(iterator) * batch_size):4f}, Accuracy: {acc/(len(iterator) * batch_size):.4f}")
		f.close()
	return epoch_loss / len(iterator), epoch_bleus / (len(iterator) * batch_size), acc/(len(iterator) * batch_size)

def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
# Training
best_valid_loss = float('inf')

if train_mode:
	train_losses = []
	valid_losses = []
	train_bleus = []
	valid_bleus = []

	for epoch in range(N_EPOCHS):
		
		start_time = time.time()
		
		train_loss, train_bleu = train(model, train_iterator, optimizer, criterion, CLIP, BATCH_SIZE)
		valid_loss, valid_bleu, valid_acc = evaluate(model, valid_iterator, criterion, TEST_BATCH_SIZE)
		
		end_time = time.time()
		
		epoch_mins, epoch_secs = epoch_time(start_time, end_time)
		
		if valid_loss < best_valid_loss:
			best_valid_loss = valid_loss
			torch.save(model.state_dict(), model_root / f'{model_name}.pt')
		
		print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
		print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f} | Train Bleu: {train_bleu:.3f}')
		print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f} | Val. Bleu: {valid_bleu:.3f} | Accuracy: {valid_acc:.4f}')
		train_losses.append(train_loss)
		valid_losses.append(valid_loss)
		train_bleus.append(train_bleu)
		valid_bleus.append(valid_bleu)
    
		if epoch % plot_steps == 0:
			train_visualize(train_losses, valid_losses, datatype="Loss")
			train_visualize(train_bleus, valid_bleus, datatype="Bleu")
	
	train_visualize(train_losses, valid_losses, datatype="Loss")
	train_visualize(train_bleus, valid_bleus, datatype="Bleu")
# Out:
# Epoch: 01 | Time: 0m 4s
# 	Train Loss: 3.329 | Train PPL:  27.908 | Train Bleu: 0.002
# 	 Val. Loss: 3.313 |  Val. PPL:  27.461 | Val. Bleu: 0.031 | Accuracy: 0.0000
# Epoch: 02 | Time: 0m 5s
# 	Train Loss: 3.261 | Train PPL:  26.087 | Train Bleu: 0.023
# 	 Val. Loss: 3.225 |  Val. PPL:  25.144 | Val. Bleu: 0.024 | Accuracy: 0.0000
# Epoch: 03 | Time: 0m 5s
# 	Train Loss: 3.213 | Train PPL:  24.845 | Train Bleu: 0.026
# 	 Val. Loss: 3.176 |  Val. PPL:  23.948 | Val. Bleu: 0.023 | Accuracy: 0.0000
# Epoch: 04 | Time: 0m 5s
# 	Train Loss: 3.197 | Train PPL:  24.457 | Train Bleu: 0.029
# 	 Val. Loss: 3.205 |  Val. PPL:  24.660 | Val. Bleu: 0.027 | Accuracy: 0.0000
# Epoch: 05 | Time: 0m 5s
# 	Train Loss: 3.174 | Train PPL:  23.912 | Train Bleu: 0.031
# 	 Val. Loss: 3.174 |  Val. PPL:  23.894 | Val. Bleu: 0.026 | Accuracy: 0.0000
# Epoch: 06 | Time: 0m 5s
# 	Train Loss: 3.160 | Train PPL:  23.577 | Train Bleu: 0.031
# 	 Val. Loss: 3.171 |  Val. PPL:  23.841 | Val. Bleu: 0.026 | Accuracy: 0.0000
# Epoch: 07 | Time: 0m 5s
# 	Train Loss: 3.147 | Train PPL:  23.276 | Train Bleu: 0.032
# 	 Val. Loss: 3.167 |  Val. PPL:  23.746 | Val. Bleu: 0.026 | Accuracy: 0.0000
# Epoch: 08 | Time: 0m 5s
# 	Train Loss: 3.143 | Train PPL:  23.174 | Train Bleu: 0.032
# 	 Val. Loss: 3.169 |  Val. PPL:  23.772 | Val. Bleu: 0.026 | Accuracy: 0.0000
# Epoch: 09 | Time: 0m 5s
# 	Train Loss: 3.125 | Train PPL:  22.771 | Train Bleu: 0.032
# 	 Val. Loss: 3.162 |  Val. PPL:  23.610 | Val. Bleu: 0.025 | Accuracy: 0.0000
# Epoch: 10 | Time: 0m 5s
# 	Train Loss: 3.102 | Train PPL:  22.246 | Train Bleu: 0.032
# 	 Val. Loss: 3.162 |  Val. PPL:  23.624 | Val. Bleu: 0.026 | Accuracy: 0.0000
# Epoch: 11 | Time: 0m 5s
# 	Train Loss: 3.109 | Train PPL:  22.396 | Train Bleu: 0.032
# 	 Val. Loss: 3.194 |  Val. PPL:  24.385 | Val. Bleu: 0.027 | Accuracy: 0.0000
# 	Train Loss: 1.691 | Train PPL:   5.427 | Train Bleu: 0.259
# 	 Val. Loss: 2.460 |  Val. PPL:  11.700 | Val. Bleu: 0.355 | Accuracy: 0.1020
# Epoch: 199 | Time: 0m 9s
# 	Train Loss: 1.697 | Train PPL:   5.456 | Train Bleu: 0.262
# 	 Val. Loss: 2.440 |  Val. PPL:  11.471 | Val. Bleu: 0.365 | Accuracy: 0.1020
# Epoch: 200 | Time: 0m 8s
# 	Train Loss: 1.698 | Train PPL:   5.466 | Train Bleu: 0.261
# 	 Val. Loss: 2.432 |  Val. PPL:  11.378 | Val. Bleu: 0.371 | Accuracy: 0.1224
# Epoch: 201 | Time: 0m 6s
# 	Train Loss: 1.675 | Train PPL:   5.341 | Train Bleu: 0.269
# 	 Val. Loss: 2.486 |  Val. PPL:  12.010 | Val. Bleu: 0.383 | Accuracy: 0.1224
# Epoch: 202 | Time: 0m 7s
# 	Train Loss: 1.679 | Train PPL:   5.358 | Train Bleu: 0.272
# 	 Val. Loss: 2.447 |  Val. PPL:  11.556 | Val. Bleu: 0.363 | Accuracy: 0.1224
# Epoch: 203 | Time: 0m 7s
# 	Train Loss: 1.680 | Train PPL:   5.366 | Train Bleu: 0.272
# 	 Val. Loss: 2.438 |  Val. PPL:  11.446 | Val. Bleu: 0.380 | Accuracy: 0.1020
# Epoch: 204 | Time: 0m 7s
# 	Train Loss: 1.667 | Train PPL:   5.297 | Train Bleu: 0.276
# 	 Val. Loss: 2.458 |  Val. PPL:  11.687 | Val. Bleu: 0.402 | Accuracy: 0.1633
# Epoch: 205 | Time: 0m 8s
# 	Train Loss: 1.670 | Train PPL:   5.314 | Train Bleu: 0.280
# 	 Val. Loss: 2.440 |  Val. PPL:  11.471 | Val. Bleu: 0.376 | Accuracy: 0.1224
# Epoch: 206 | Time: 0m 8s
# 	Train Loss: 1.659 | Train PPL:   5.253 | Train Bleu: 0.283
# 	 Val. Loss: 2.458 |  Val. PPL:  11.681 | Val. Bleu: 0.384 | Accuracy: 0.1633
# Epoch: 207 | Time: 0m 6s
# 	Train Loss: 1.670 | Train PPL:   5.310 | Train Bleu: 0.285
# 	 Val. Loss: 2.434 |  Val. PPL:  11.408 | Val. Bleu: 0.401 | Accuracy: 0.1633
# Epoch: 208 | Time: 0m 6s
# 	Train Loss: 1.666 | Train PPL:   5.292 | Train Bleu: 0.287
# 	 Val. Loss: 2.450 |  Val. PPL:  11.585 | Val. Bleu: 0.411 | Accuracy: 0.1837
# Epoch: 209 | Time: 0m 6s
# 	Train Loss: 1.645 | Train PPL:   5.179 | Train Bleu: 0.289
# 	 Val. Loss: 2.429 |  Val. PPL:  11.351 | Val. Bleu: 0.396 | Accuracy: 0.1633
# Epoch: 210 | Time: 0m 6s
# 	Train Loss: 1.635 | Train PPL:   5.131 | Train Bleu: 0.293
# 	 Val. Loss: 2.435 |  Val. PPL:  11.414 | Val. Bleu: 0.415 | Accuracy: 0.1633
# Epoch: 211 | Time: 0m 6s
# 	Train Loss: 1.647 | Train PPL:   5.191 | Train Bleu: 0.293
# Epoch: 225 | Time: 0m 6s
# 	Train Loss: 1.605 | Train PPL:   4.977 | Train Bleu: 0.331
# 	 Val. Loss: 2.458 |  Val. PPL:  11.684 | Val. Bleu: 0.438 | Accuracy: 0.2041
# Epoch: 226 | Time: 0m 6s
# 	Train Loss: 1.602 | Train PPL:   4.961 | Train Bleu: 0.336
# 	 Val. Loss: 2.435 |  Val. PPL:  11.412 | Val. Bleu: 0.464 | Accuracy: 0.2245
# Epoch: 227 | Time: 0m 6s
# 	Train Loss: 1.606 | Train PPL:   4.982 | Train Bleu: 0.334
# 	 Val. Loss: 2.442 |  Val. PPL:  11.496 | Val. Bleu: 0.462 | Accuracy: 0.2245
# Epoch: 228 | Time: 0m 6s
# 	Train Loss: 1.608 | Train PPL:   4.993 | Train Bleu: 0.338
# 	 Val. Loss: 2.438 |  Val. PPL:  11.451 | Val. Bleu: 0.459 | Accuracy: 0.2041
# Epoch: 229 | Time: 0m 6s
# 	Train Loss: 1.600 | Train PPL:   4.953 | Train Bleu: 0.339
# 	 Val. Loss: 2.452 |  Val. PPL:  11.608 | Val. Bleu: 0.467 | Accuracy: 0.2245
# Epoch: 230 | Time: 0m 6s
# 	Train Loss: 1.583 | Train PPL:   4.868 | Train Bleu: 0.340
# 	 Val. Loss: 2.428 |  Val. PPL:  11.338 | Val. Bleu: 0.464 | Accuracy: 0.2245
# Epoch: 231 | Time: 0m 6s
# 	Train Loss: 1.598 | Train PPL:   4.942 | Train Bleu: 0.345
# 	 Val. Loss: 2.426 |  Val. PPL:  11.308 | Val. Bleu: 0.487 | Accuracy: 0.2449
# Epoch: 232 | Time: 0m 6s
# 	Train Loss: 1.600 | Train PPL:   4.952 | Train Bleu: 0.345
# 	 Val. Loss: 2.427 |  Val. PPL:  11.322 | Val. Bleu: 0.495 | Accuracy: 0.2449
# Epoch: 233 | Time: 0m 6s
# 	Train Loss: 1.595 | Train PPL:   4.927 | Train Bleu: 0.351
# 	 Val. Loss: 2.404 |  Val. PPL:  11.063 | Val. Bleu: 0.472 | Accuracy: 0.2449
# Epoch: 234 | Time: 0m 6s
# 	Train Loss: 1.592 | Train PPL:   4.912 | Train Bleu: 0.353
# 	 Val. Loss: 2.431 |  Val. PPL:  11.372 | Val. Bleu: 0.471 | Accuracy: 0.2245
# Epoch: 235 | Time: 0m 6s
# 	Train Loss: 1.581 | Train PPL:   4.861 | Train Bleu: 0.351
# 	 Val. Loss: 2.396 |  Val. PPL:  10.974 | Val. Bleu: 0.500 | Accuracy: 0.2653
# Epoch: 236 | Time: 0m 6s
# 	Train Loss: 1.584 | Train PPL:   4.876 | Train Bleu: 0.356
# 	 Val. Loss: 2.385 |  Val. PPL:  10.862 | Val. Bleu: 0.505 | Accuracy: 0.2857
# Epoch: 237 | Time: 0m 6s
# 	Train Loss: 1.589 | Train PPL:   4.897 | Train Bleu: 0.359
# 	 Val. Loss: 2.419 |  Val. PPL:  11.235 | Val. Bleu: 0.488 | Accuracy: 0.2449
# Epoch: 238 | Time: 0m 6s
# 	Train Loss: 1.571 | Train PPL:   4.811 | Train Bleu: 0.362
# 	 Val. Loss: 2.376 |  Val. PPL:  10.766 | Val. Bleu: 0.490 | Accuracy: 0.2653
# Epoch: 239 | Time: 0m 6s
# 	Train Loss: 1.572 | Train PPL:   4.816 | Train Bleu: 0.362
# 	 Val. Loss: 2.383 |  Val. PPL:  10.840 | Val. Bleu: 0.503 | Accuracy: 0.2857
# Epoch: 240 | Time: 0m 6s
# 	Train Loss: 1.572 | Train PPL:   4.818 | Train Bleu: 0.366
# 	 Val. Loss: 2.391 |  Val. PPL:  10.929 | Val. Bleu: 0.519 | Accuracy: 0.3061
# Epoch: 241 | Time: 0m 6s
# 	Train Loss: 1.572 | Train PPL:   4.818 | Train Bleu: 0.368
# 	 Val. Loss: 2.397 |  Val. PPL:  10.986 | Val. Bleu: 0.492 | Accuracy: 0.2653
# Epoch: 242 | Time: 0m 6s
# 	Train Loss: 1.565 | Train PPL:   4.783 | Train Bleu: 0.370
# 	 Val. Loss: 2.434 |  Val. PPL:  11.407 | Val. Bleu: 0.476 | Accuracy: 0.2245
# Epoch: 243 | Time: 0m 6s
# 	Train Loss: 1.565 | Train PPL:   4.782 | Train Bleu: 0.372
# 	 Val. Loss: 2.423 |  Val. PPL:  11.276 | Val. Bleu: 0.477 | Accuracy: 0.2245
# Epoch: 244 | Time: 0m 6s
# 	Train Loss: 1.569 | Train PPL:   4.800 | Train Bleu: 0.376
# 	 Val. Loss: 2.351 |  Val. PPL:  10.497 | Val. Bleu: 0.463 | Accuracy: 0.2653
# Epoch: 245 | Time: 0m 6s
# 	Train Loss: 1.564 | Train PPL:   4.779 | Train Bleu: 0.374
# 	 Val. Loss: 2.397 |  Val. PPL:  10.990 | Val. Bleu: 0.504 | Accuracy: 0.2653
# Epoch: 246 | Time: 0m 6s
# 	Train Loss: 1.558 | Train PPL:   4.749 | Train Bleu: 0.379
# 	 Val. Loss: 2.342 |  Val. PPL:  10.403 | Val. Bleu: 0.503 | Accuracy: 0.2857
# Epoch: 247 | Time: 0m 6s
# 	Train Loss: 1.564 | Train PPL:   4.778 | Train Bleu: 0.382
# 	 Val. Loss: 2.365 |  Val. PPL:  10.641 | Val. Bleu: 0.492 | Accuracy: 0.2449
# Epoch: 248 | Time: 0m 6s
# 	Train Loss: 1.550 | Train PPL:   4.712 | Train Bleu: 0.384
# 	 Val. Loss: 2.433 |  Val. PPL:  11.394 | Val. Bleu: 0.478 | Accuracy: 0.2449
# Epoch: 249 | Time: 0m 6s
# 	Train Loss: 1.560 | Train PPL:   4.757 | Train Bleu: 0.386
# 	 Val. Loss: 2.409 |  Val. PPL:  11.125 | Val. Bleu: 0.492 | Accuracy: 0.2449
# Epoch: 250 | Time: 0m 6s
# 	Train Loss: 1.549 | Train PPL:   4.705 | Train Bleu: 0.388
# 	 Val. Loss: 2.370 |  Val. PPL:  10.694 | Val. Bleu: 0.497 | Accuracy: 0.2653
# Epoch: 251 | Time: 0m 6s
# 	Train Loss: 1.539 | Train PPL:   4.660 | Train Bleu: 0.391
# 	 Val. Loss: 2.365 |  Val. PPL:  10.643 | Val. Bleu: 0.491 | Accuracy: 0.2449
# Epoch: 252 | Time: 0m 6s
# 	Train Loss: 1.541 | Train PPL:   4.670 | Train Bleu: 0.390
# 	 Val. Loss: 2.331 |  Val. PPL:  10.293 | Val. Bleu: 0.523 | Accuracy: 0.2653
# Epoch: 253 | Time: 0m 6s
# 	Train Loss: 1.540 | Train PPL:   4.664 | Train Bleu: 0.393
# 	 Val. Loss: 2.354 |  Val. PPL:  10.532 | Val. Bleu: 0.506 | Accuracy: 0.2449
# Epoch: 254 | Time: 0m 6s
# 	Train Loss: 1.530 | Train PPL:   4.617 | Train Bleu: 0.393
# 	 Val. Loss: 2.365 |  Val. PPL:  10.645 | Val. Bleu: 0.497 | Accuracy: 0.2653
# Epoch: 255 | Time: 0m 6s
# 	Train Loss: 1.541 | Train PPL:   4.671 | Train Bleu: 0.396
# 	 Val. Loss: 2.367 |  Val. PPL:  10.661 | Val. Bleu: 0.532 | Accuracy: 0.2857
# Epoch: 256 | Time: 0m 6s
# 	Train Loss: 1.542 | Train PPL:   4.675 | Train Bleu: 0.399
# 	 Val. Loss: 2.387 |  Val. PPL:  10.876 | Val. Bleu: 0.501 | Accuracy: 0.2449
# Epoch: 257 | Time: 0m 6s
# 	Train Loss: 1.540 | Train PPL:   4.667 | Train Bleu: 0.397
# 	 Val. Loss: 2.394 |  Val. PPL:  10.959 | Val. Bleu: 0.517 | Accuracy: 0.2449
# Epoch: 258 | Time: 0m 6s
# 	Train Loss: 1.538 | Train PPL:   4.657 | Train Bleu: 0.403
# 	 Val. Loss: 2.390 |  Val. PPL:  10.908 | Val. Bleu: 0.518 | Accuracy: 0.2653
# Epoch: 259 | Time: 0m 6s
# 	Train Loss: 1.526 | Train PPL:   4.601 | Train Bleu: 0.410
# 	 Val. Loss: 2.326 |  Val. PPL:  10.233 | Val. Bleu: 0.503 | Accuracy: 0.2653
# Epoch: 260 | Time: 0m 6s
# 	Train Loss: 1.525 | Train PPL:   4.593 | Train Bleu: 0.409
# 	 Val. Loss: 2.359 |  Val. PPL:  10.576 | Val. Bleu: 0.566 | Accuracy: 0.3265
# Epoch: 261 | Time: 0m 6s
# 	Train Loss: 1.533 | Train PPL:   4.633 | Train Bleu: 0.412
# 	 Val. Loss: 2.354 |  Val. PPL:  10.522 | Val. Bleu: 0.547 | Accuracy: 0.3061
# Epoch: 262 | Time: 0m 6s
# 	Train Loss: 1.518 | Train PPL:   4.561 | Train Bleu: 0.414
# 	 Val. Loss: 2.340 |  Val. PPL:  10.385 | Val. Bleu: 0.549 | Accuracy: 0.2857
# Epoch: 263 | Time: 0m 6s
# 	Train Loss: 1.512 | Train PPL:   4.535 | Train Bleu: 0.417
# 	 Val. Loss: 2.376 |  Val. PPL:  10.758 | Val. Bleu: 0.538 | Accuracy: 0.2653
# Epoch: 264 | Time: 0m 6s
# 	Train Loss: 1.513 | Train PPL:   4.540 | Train Bleu: 0.417
# 	 Val. Loss: 2.361 |  Val. PPL:  10.600 | Val. Bleu: 0.561 | Accuracy: 0.3061
# Epoch: 265 | Time: 0m 6s
# 	Train Loss: 1.527 | Train PPL:   4.605 | Train Bleu: 0.420
# 	 Val. Loss: 2.330 |  Val. PPL:  10.281 | Val. Bleu: 0.551 | Accuracy: 0.3265
# Epoch: 266 | Time: 0m 6s
# 	Train Loss: 1.503 | Train PPL:   4.495 | Train Bleu: 0.426
# 	 Val. Loss: 2.373 |  Val. PPL:  10.732 | Val. Bleu: 0.525 | Accuracy: 0.2857
# Epoch: 267 | Time: 0m 6s
# 	Train Loss: 1.510 | Train PPL:   4.528 | Train Bleu: 0.423
# 	 Val. Loss: 2.355 |  Val. PPL:  10.534 | Val. Bleu: 0.532 | Accuracy: 0.2857
# Epoch: 268 | Time: 0m 6s
# 	Train Loss: 1.506 | Train PPL:   4.507 | Train Bleu: 0.429
# 	 Val. Loss: 2.376 |  Val. PPL:  10.764 | Val. Bleu: 0.562 | Accuracy: 0.3265
# Epoch: 269 | Time: 0m 6s
# 	Train Loss: 1.505 | Train PPL:   4.503 | Train Bleu: 0.428
# 	 Val. Loss: 2.405 |  Val. PPL:  11.079 | Val. Bleu: 0.513 | Accuracy: 0.2653
# Epoch: 270 | Time: 0m 6s
# 	Train Loss: 1.499 | Train PPL:   4.478 | Train Bleu: 0.433
# 	 Val. Loss: 2.381 |  Val. PPL:  10.818 | Val. Bleu: 0.544 | Accuracy: 0.2857
# Epoch: 271 | Time: 0m 6s
# 	Train Loss: 1.504 | Train PPL:   4.500 | Train Bleu: 0.434
# 	 Val. Loss: 2.335 |  Val. PPL:  10.329 | Val. Bleu: 0.556 | Accuracy: 0.3061
# Epoch: 272 | Time: 0m 6s
# 	Train Loss: 1.498 | Train PPL:   4.474 | Train Bleu: 0.436
# 	 Val. Loss: 2.362 |  Val. PPL:  10.609 | Val. Bleu: 0.539 | Accuracy: 0.3061
# Epoch: 273 | Time: 0m 6s
# 	Train Loss: 1.500 | Train PPL:   4.484 | Train Bleu: 0.439
# 	 Val. Loss: 2.336 |  Val. PPL:  10.338 | Val. Bleu: 0.582 | Accuracy: 0.3265
# Epoch: 274 | Time: 0m 6s
# 	Train Loss: 1.496 | Train PPL:   4.466 | Train Bleu: 0.440
# 	 Val. Loss: 2.319 |  Val. PPL:  10.161 | Val. Bleu: 0.537 | Accuracy: 0.3061
# Epoch: 275 | Time: 0m 6s
# 	Train Loss: 1.492 | Train PPL:   4.445 | Train Bleu: 0.441
# 	 Val. Loss: 2.336 |  Val. PPL:  10.338 | Val. Bleu: 0.605 | Accuracy: 0.3469
# Epoch: 276 | Time: 0m 6s
# 	Train Loss: 1.496 | Train PPL:   4.466 | Train Bleu: 0.445
# 	 Val. Loss: 2.328 |  Val. PPL:  10.253 | Val. Bleu: 0.548 | Accuracy: 0.3061
# Epoch: 277 | Time: 0m 6s
# 	Train Loss: 1.499 | Train PPL:   4.477 | Train Bleu: 0.448
# 	 Val. Loss: 2.295 |  Val. PPL:   9.926 | Val. Bleu: 0.599 | Accuracy: 0.3673
# Epoch: 278 | Time: 0m 6s
# 	Train Loss: 1.491 | Train PPL:   4.444 | Train Bleu: 0.449
# 	 Val. Loss: 2.381 |  Val. PPL:  10.818 | Val. Bleu: 0.563 | Accuracy: 0.3265
# Epoch: 279 | Time: 0m 6s
# 	Train Loss: 1.489 | Train PPL:   4.435 | Train Bleu: 0.453
# 	 Val. Loss: 2.327 |  Val. PPL:  10.252 | Val. Bleu: 0.570 | Accuracy: 0.3265
# Epoch: 280 | Time: 0m 6s
# 	Train Loss: 1.484 | Train PPL:   4.409 | Train Bleu: 0.457
# 	 Val. Loss: 2.349 |  Val. PPL:  10.480 | Val. Bleu: 0.534 | Accuracy: 0.2857
# Epoch: 281 | Time: 0m 7s
# 	Train Loss: 1.492 | Train PPL:   4.445 | Train Bleu: 0.458
# 	 Val. Loss: 2.359 |  Val. PPL:  10.578 | Val. Bleu: 0.591 | Accuracy: 0.3469
# Epoch: 282 | Time: 0m 6s
# 	Train Loss: 1.483 | Train PPL:   4.406 | Train Bleu: 0.459
# 	 Val. Loss: 2.326 |  Val. PPL:  10.240 | Val. Bleu: 0.609 | Accuracy: 0.3469
# Epoch: 283 | Time: 0m 6s
# 	Train Loss: 1.474 | Train PPL:   4.366 | Train Bleu: 0.461
# 	 Val. Loss: 2.287 |  Val. PPL:   9.844 | Val. Bleu: 0.607 | Accuracy: 0.3673
# Epoch: 284 | Time: 0m 6s
# 	Train Loss: 1.479 | Train PPL:   4.388 | Train Bleu: 0.459
# 	 Val. Loss: 2.311 |  Val. PPL:  10.082 | Val. Bleu: 0.588 | Accuracy: 0.3265
# Epoch: 285 | Time: 0m 6s
# 	Train Loss: 1.479 | Train PPL:   4.390 | Train Bleu: 0.463
# 	 Val. Loss: 2.298 |  Val. PPL:   9.950 | Val. Bleu: 0.585 | Accuracy: 0.3265
# Epoch: 286 | Time: 0m 6s
# 	Train Loss: 1.461 | Train PPL:   4.312 | Train Bleu: 0.472
# 	 Val. Loss: 2.358 |  Val. PPL:  10.575 | Val. Bleu: 0.574 | Accuracy: 0.3061
# Epoch: 287 | Time: 0m 7s
# 	Train Loss: 1.476 | Train PPL:   4.373 | Train Bleu: 0.471
# 	 Val. Loss: 2.309 |  Val. PPL:  10.062 | Val. Bleu: 0.607 | Accuracy: 0.3673
# Epoch: 288 | Time: 0m 9s
# 	Train Loss: 1.453 | Train PPL:   4.275 | Train Bleu: 0.469
# 	 Val. Loss: 2.319 |  Val. PPL:  10.163 | Val. Bleu: 0.587 | Accuracy: 0.3673
# Epoch: 289 | Time: 0m 8s
# 	Train Loss: 1.458 | Train PPL:   4.297 | Train Bleu: 0.473
# 	 Val. Loss: 2.304 |  Val. PPL:  10.016 | Val. Bleu: 0.609 | Accuracy: 0.3878
# Epoch: 290 | Time: 0m 6s
# 	Train Loss: 1.466 | Train PPL:   4.333 | Train Bleu: 0.476
# 	 Val. Loss: 2.333 |  Val. PPL:  10.308 | Val. Bleu: 0.578 | Accuracy: 0.3673
# Epoch: 291 | Time: 0m 6s
# 	Train Loss: 1.466 | Train PPL:   4.331 | Train Bleu: 0.477
# 	 Val. Loss: 2.328 |  Val. PPL:  10.256 | Val. Bleu: 0.600 | Accuracy: 0.3878
# Epoch: 292 | Time: 0m 6s
# 	Train Loss: 1.453 | Train PPL:   4.276 | Train Bleu: 0.482
# 	 Val. Loss: 2.303 |  Val. PPL:  10.007 | Val. Bleu: 0.588 | Accuracy: 0.3469
# Epoch: 293 | Time: 0m 6s
# 	Train Loss: 1.454 | Train PPL:   4.279 | Train Bleu: 0.483
# 	 Val. Loss: 2.338 |  Val. PPL:  10.360 | Val. Bleu: 0.594 | Accuracy: 0.3673
# Epoch: 294 | Time: 0m 6s
# 	Train Loss: 1.457 | Train PPL:   4.292 | Train Bleu: 0.486
# 	 Val. Loss: 2.264 |  Val. PPL:   9.619 | Val. Bleu: 0.576 | Accuracy: 0.3673
# Epoch: 295 | Time: 0m 6s
# 	Train Loss: 1.449 | Train PPL:   4.259 | Train Bleu: 0.487
# 	 Val. Loss: 2.354 |  Val. PPL:  10.528 | Val. Bleu: 0.582 | Accuracy: 0.3265
# ...
# Epoch: 403 | Time: 0m 6s
# 	Train Loss: 1.232 | Train PPL:   3.428 | Train Bleu: 0.754
# 	 Val. Loss: 2.021 |  Val. PPL:   7.548 | Val. Bleu: 0.770 | Accuracy: 0.6531
# Epoch: 404 | Time: 0m 6s
# 	Train Loss: 1.231 | Train PPL:   3.425 | Train Bleu: 0.755
# 	 Val. Loss: 2.028 |  Val. PPL:   7.602 | Val. Bleu: 0.780 | Accuracy: 0.6735
# Epoch: 405 | Time: 0m 6s
# 	Train Loss: 1.217 | Train PPL:   3.378 | Train Bleu: 0.760
# 	 Val. Loss: 2.021 |  Val. PPL:   7.547 | Val. Bleu: 0.827 | Accuracy: 0.7347
# Epoch: 406 | Time: 0m 6s
# 	Train Loss: 1.227 | Train PPL:   3.411 | Train Bleu: 0.758
# 	 Val. Loss: 1.981 |  Val. PPL:   7.251 | Val. Bleu: 0.843 | Accuracy: 0.7959
# Epoch: 407 | Time: 0m 6s
# 	Train Loss: 1.225 | Train PPL:   3.403 | Train Bleu: 0.762
# 	 Val. Loss: 1.995 |  Val. PPL:   7.349 | Val. Bleu: 0.813 | Accuracy: 0.7143
# Epoch: 408 | Time: 0m 6s
# 	Train Loss: 1.224 | Train PPL:   3.401 | Train Bleu: 0.767
# 	 Val. Loss: 1.945 |  Val. PPL:   6.991 | Val. Bleu: 0.822 | Accuracy: 0.7347
# Epoch: 409 | Time: 0m 6s
# 	Train Loss: 1.222 | Train PPL:   3.395 | Train Bleu: 0.765
# 	 Val. Loss: 1.960 |  Val. PPL:   7.100 | Val. Bleu: 0.832 | Accuracy: 0.7959
# Epoch: 410 | Time: 0m 6s
# 	Train Loss: 1.215 | Train PPL:   3.369 | Train Bleu: 0.772
# 	 Val. Loss: 1.997 |  Val. PPL:   7.370 | Val. Bleu: 0.798 | Accuracy: 0.7347
# Epoch: 411 | Time: 0m 6s
# 	Train Loss: 1.217 | Train PPL:   3.376 | Train Bleu: 0.774
# 	 Val. Loss: 1.979 |  Val. PPL:   7.232 | Val. Bleu: 0.853 | Accuracy: 0.7551
# 	 Val. Loss: 1.968 |  Val. PPL:   7.155 | Val. Bleu: 0.912 | Accuracy: 0.8776
# Epoch: 439 | Time: 0m 6s
# 	Train Loss: 1.179 | Train PPL:   3.252 | Train Bleu: 0.828
# 	 Val. Loss: 2.006 |  Val. PPL:   7.434 | Val. Bleu: 0.852 | Accuracy: 0.7755
# Epoch: 440 | Time: 0m 6s
# 	Train Loss: 1.178 | Train PPL:   3.247 | Train Bleu: 0.829
# 	 Val. Loss: 1.943 |  Val. PPL:   6.977 | Val. Bleu: 0.878 | Accuracy: 0.8163
# Epoch: 441 | Time: 0m 6s
# 	Train Loss: 1.174 | Train PPL:   3.235 | Train Bleu: 0.830
# 	 Val. Loss: 1.952 |  Val. PPL:   7.045 | Val. Bleu: 0.857 | Accuracy: 0.7755
# Epoch: 442 | Time: 0m 6s
# 	Train Loss: 1.183 | Train PPL:   3.263 | Train Bleu: 0.831
# 	 Val. Loss: 1.958 |  Val. PPL:   7.086 | Val. Bleu: 0.894 | Accuracy: 0.8367
# Epoch: 443 | Time: 0m 6s
# 	Train Loss: 1.181 | Train PPL:   3.258 | Train Bleu: 0.833
# 	 Val. Loss: 1.950 |  Val. PPL:   7.028 | Val. Bleu: 0.908 | Accuracy: 0.8367
# Epoch: 444 | Time: 0m 6s
# 	Train Loss: 1.175 | Train PPL:   3.239 | Train Bleu: 0.835
# 	 Val. Loss: 1.945 |  Val. PPL:   6.991 | Val. Bleu: 0.900 | Accuracy: 0.8571
# Epoch: 445 | Time: 0m 6s
# 	Train Loss: 1.178 | Train PPL:   3.246 | Train Bleu: 0.837
# 	 Val. Loss: 1.983 |  Val. PPL:   7.268 | Val. Bleu: 0.845 | Accuracy: 0.7755
# Epoch: 446 | Time: 0m 6s
# 	Train Loss: 1.170 | Train PPL:   3.222 | Train Bleu: 0.839
# 	 Val. Loss: 1.956 |  Val. PPL:   7.068 | Val. Bleu: 0.890 | Accuracy: 0.8367
# Epoch: 447 | Time: 0m 6s
# 	Train Loss: 1.178 | Train PPL:   3.247 | Train Bleu: 0.843
# 	 Val. Loss: 1.976 |  Val. PPL:   7.214 | Val. Bleu: 0.834 | Accuracy: 0.7551
# Epoch: 448 | Time: 0m 6s
# 	Train Loss: 1.170 | Train PPL:   3.221 | Train Bleu: 0.842
# 	 Val. Loss: 1.951 |  Val. PPL:   7.035 | Val. Bleu: 0.886 | Accuracy: 0.8367
# Epoch: 449 | Time: 0m 6s
# 	Train Loss: 1.179 | Train PPL:   3.252 | Train Bleu: 0.844
# 	 Val. Loss: 1.969 |  Val. PPL:   7.165 | Val. Bleu: 0.880 | Accuracy: 0.8163
# Epoch: 450 | Time: 0m 6s
# 	Train Loss: 1.175 | Train PPL:   3.239 | Train Bleu: 0.848
# 	 Val. Loss: 1.959 |  Val. PPL:   7.093 | Val. Bleu: 0.906 | Accuracy: 0.8776
# Epoch: 451 | Time: 0m 6s
# 	Train Loss: 1.171 | Train PPL:   3.227 | Train Bleu: 0.847
# 	 Val. Loss: 1.941 |  Val. PPL:   6.963 | Val. Bleu: 0.894 | Accuracy: 0.8367
# Epoch: 452 | Time: 0m 6s
# 	Train Loss: 1.169 | Train PPL:   3.217 | Train Bleu: 0.849
# 	 Val. Loss: 1.947 |  Val. PPL:   7.005 | Val. Bleu: 0.915 | Accuracy: 0.8776
# Epoch: 453 | Time: 0m 6s
# 	Train Loss: 1.163 | Train PPL:   3.201 | Train Bleu: 0.850
# 	 Val. Loss: 1.964 |  Val. PPL:   7.129 | Val. Bleu: 0.898 | Accuracy: 0.8367
# Epoch: 454 | Time: 0m 6s
# 	Train Loss: 1.171 | Train PPL:   3.226 | Train Bleu: 0.851
# 	 Val. Loss: 1.943 |  Val. PPL:   6.978 | Val. Bleu: 0.934 | Accuracy: 0.8980
# Epoch: 455 | Time: 0m 6s
# 	Train Loss: 1.169 | Train PPL:   3.219 | Train Bleu: 0.850
# 	 Val. Loss: 1.968 |  Val. PPL:   7.156 | Val. Bleu: 0.898 | Accuracy: 0.8571
# Epoch: 456 | Time: 0m 6s
# 	Train Loss: 1.159 | Train PPL:   3.187 | Train Bleu: 0.854
# 	 Val. Loss: 1.944 |  Val. PPL:   6.987 | Val. Bleu: 0.909 | Accuracy: 0.8571
# Epoch: 457 | Time: 0m 6s
# 	Train Loss: 1.164 | Train PPL:   3.202 | Train Bleu: 0.857
# 	 Val. Loss: 1.948 |  Val. PPL:   7.017 | Val. Bleu: 0.860 | Accuracy: 0.7755
# Epoch: 458 | Time: 0m 7s
# 	Train Loss: 1.164 | Train PPL:   3.203 | Train Bleu: 0.858
# 	 Val. Loss: 1.942 |  Val. PPL:   6.973 | Val. Bleu: 0.903 | Accuracy: 0.8367
# Epoch: 459 | Time: 0m 6s
# 	Train Loss: 1.159 | Train PPL:   3.188 | Train Bleu: 0.860
# 	 Val. Loss: 1.954 |  Val. PPL:   7.058 | Val. Bleu: 0.883 | Accuracy: 0.8163
# Epoch: 460 | Time: 0m 6s
# 	Train Loss: 1.164 | Train PPL:   3.203 | Train Bleu: 0.857
# 	 Val. Loss: 1.949 |  Val. PPL:   7.019 | Val. Bleu: 0.895 | Accuracy: 0.8367
# Epoch: 461 | Time: 0m 6s
# 	Train Loss: 1.165 | Train PPL:   3.206 | Train Bleu: 0.859
# 	 Val. Loss: 1.973 |  Val. PPL:   7.193 | Val. Bleu: 0.884 | Accuracy: 0.8163
# Epoch: 462 | Time: 0m 6s
# 	Train Loss: 1.167 | Train PPL:   3.213 | Train Bleu: 0.860
# 	 Val. Loss: 1.955 |  Val. PPL:   7.061 | Val. Bleu: 0.911 | Accuracy: 0.8571
# Epoch: 463 | Time: 0m 6s
# 	Train Loss: 1.161 | Train PPL:   3.193 | Train Bleu: 0.867
# 	 Val. Loss: 1.953 |  Val. PPL:   7.049 | Val. Bleu: 0.905 | Accuracy: 0.8571
# Epoch: 464 | Time: 0m 6s
# 	Train Loss: 1.165 | Train PPL:   3.206 | Train Bleu: 0.859
# 	 Val. Loss: 1.938 |  Val. PPL:   6.945 | Val. Bleu: 0.897 | Accuracy: 0.8367
# Epoch: 465 | Time: 0m 6s
# 	Train Loss: 1.157 | Train PPL:   3.180 | Train Bleu: 0.864
# 	 Val. Loss: 1.989 |  Val. PPL:   7.308 | Val. Bleu: 0.862 | Accuracy: 0.7551
# Epoch: 466 | Time: 0m 6s
# 	Train Loss: 1.154 | Train PPL:   3.172 | Train Bleu: 0.868
# 	 Val. Loss: 1.968 |  Val. PPL:   7.156 | Val. Bleu: 0.895 | Accuracy: 0.8163
# Epoch: 467 | Time: 0m 6s
# 	Train Loss: 1.159 | Train PPL:   3.187 | Train Bleu: 0.868
# 	 Val. Loss: 1.973 |  Val. PPL:   7.192 | Val. Bleu: 0.907 | Accuracy: 0.8367
# Epoch: 468 | Time: 0m 6s
# 	Train Loss: 1.157 | Train PPL:   3.182 | Train Bleu: 0.866
# 	 Val. Loss: 1.947 |  Val. PPL:   7.006 | Val. Bleu: 0.926 | Accuracy: 0.8571
# Epoch: 469 | Time: 0m 6s
# 	Train Loss: 1.157 | Train PPL:   3.181 | Train Bleu: 0.870
# 	 Val. Loss: 1.950 |  Val. PPL:   7.029 | Val. Bleu: 0.886 | Accuracy: 0.8163
# Epoch: 470 | Time: 0m 6s
# 	Train Loss: 1.158 | Train PPL:   3.183 | Train Bleu: 0.870
# 	 Val. Loss: 1.989 |  Val. PPL:   7.308 | Val. Bleu: 0.879 | Accuracy: 0.7959
# Epoch: 471 | Time: 0m 6s
# 	Train Loss: 1.155 | Train PPL:   3.175 | Train Bleu: 0.872
# 	 Val. Loss: 1.966 |  Val. PPL:   7.141 | Val. Bleu: 0.900 | Accuracy: 0.8367
# Epoch: 472 | Time: 0m 6s
# 	Train Loss: 1.150 | Train PPL:   3.158 | Train Bleu: 0.872
# 	 Val. Loss: 1.938 |  Val. PPL:   6.946 | Val. Bleu: 0.910 | Accuracy: 0.8367
# Epoch: 473 | Time: 0m 6s
# 	Train Loss: 1.150 | Train PPL:   3.158 | Train Bleu: 0.878
# 	 Val. Loss: 1.975 |  Val. PPL:   7.206 | Val. Bleu: 0.927 | Accuracy: 0.8571
# Epoch: 474 | Time: 0m 6s
# 	Train Loss: 1.153 | Train PPL:   3.167 | Train Bleu: 0.877
# 	 Val. Loss: 1.951 |  Val. PPL:   7.036 | Val. Bleu: 0.903 | Accuracy: 0.8163
# Epoch: 475 | Time: 0m 6s
# 	Train Loss: 1.145 | Train PPL:   3.144 | Train Bleu: 0.878
# 	 Val. Loss: 1.959 |  Val. PPL:   7.091 | Val. Bleu: 0.910 | Accuracy: 0.8367
# Epoch: 476 | Time: 0m 6s
# 	Train Loss: 1.152 | Train PPL:   3.165 | Train Bleu: 0.875
# 	 Val. Loss: 1.995 |  Val. PPL:   7.356 | Val. Bleu: 0.882 | Accuracy: 0.7755
# Epoch: 477 | Time: 0m 6s
# 	Train Loss: 1.151 | Train PPL:   3.161 | Train Bleu: 0.880
# 	 Val. Loss: 1.951 |  Val. PPL:   7.036 | Val. Bleu: 0.938 | Accuracy: 0.8776
# Epoch: 478 | Time: 0m 6s
# 	Train Loss: 1.146 | Train PPL:   3.145 | Train Bleu: 0.880
# 	 Val. Loss: 1.961 |  Val. PPL:   7.108 | Val. Bleu: 0.901 | Accuracy: 0.8367
# Epoch: 479 | Time: 0m 6s
# 	Train Loss: 1.149 | Train PPL:   3.154 | Train Bleu: 0.878
# 	 Val. Loss: 1.952 |  Val. PPL:   7.043 | Val. Bleu: 0.884 | Accuracy: 0.8163
# Epoch: 480 | Time: 0m 6s
# 	Train Loss: 1.151 | Train PPL:   3.161 | Train Bleu: 0.878
# 	 Val. Loss: 1.957 |  Val. PPL:   7.080 | Val. Bleu: 0.911 | Accuracy: 0.8571
# Epoch: 481 | Time: 0m 6s
# 	Train Loss: 1.146 | Train PPL:   3.144 | Train Bleu: 0.881
# 	 Val. Loss: 1.949 |  Val. PPL:   7.022 | Val. Bleu: 0.919 | Accuracy: 0.8571
# Epoch: 482 | Time: 0m 6s
# 	Train Loss: 1.147 | Train PPL:   3.148 | Train Bleu: 0.884
# 	 Val. Loss: 1.991 |  Val. PPL:   7.325 | Val. Bleu: 0.876 | Accuracy: 0.7755
# Epoch: 483 | Time: 0m 6s
# 	Train Loss: 1.145 | Train PPL:   3.144 | Train Bleu: 0.884
# 	 Val. Loss: 1.933 |  Val. PPL:   6.909 | Val. Bleu: 0.924 | Accuracy: 0.8571
# Epoch: 484 | Time: 0m 6s
# 	Train Loss: 1.144 | Train PPL:   3.139 | Train Bleu: 0.885
# 	 Val. Loss: 1.923 |  Val. PPL:   6.842 | Val. Bleu: 0.934 | Accuracy: 0.8571
# Epoch: 485 | Time: 0m 6s
# 	Train Loss: 1.143 | Train PPL:   3.135 | Train Bleu: 0.888
# 	 Val. Loss: 1.919 |  Val. PPL:   6.816 | Val. Bleu: 0.921 | Accuracy: 0.8571
# Epoch: 486 | Time: 0m 6s
# 	Train Loss: 1.149 | Train PPL:   3.154 | Train Bleu: 0.886
# 	 Val. Loss: 1.967 |  Val. PPL:   7.152 | Val. Bleu: 0.891 | Accuracy: 0.7959
# Epoch: 487 | Time: 0m 6s
# 	Train Loss: 1.141 | Train PPL:   3.129 | Train Bleu: 0.891
# 	 Val. Loss: 1.970 |  Val. PPL:   7.172 | Val. Bleu: 0.892 | Accuracy: 0.8367
# Epoch: 488 | Time: 0m 6s
# 	Train Loss: 1.144 | Train PPL:   3.140 | Train Bleu: 0.887
# 	 Val. Loss: 1.900 |  Val. PPL:   6.686 | Val. Bleu: 0.919 | Accuracy: 0.8776
# Epoch: 489 | Time: 0m 6s
# 	Train Loss: 1.143 | Train PPL:   3.138 | Train Bleu: 0.888
# 	 Val. Loss: 2.000 |  Val. PPL:   7.390 | Val. Bleu: 0.886 | Accuracy: 0.7959
# Epoch: 490 | Time: 0m 6s
# 	Train Loss: 1.140 | Train PPL:   3.127 | Train Bleu: 0.890
# 	 Val. Loss: 1.943 |  Val. PPL:   6.980 | Val. Bleu: 0.924 | Accuracy: 0.8571
# Epoch: 491 | Time: 0m 6s
# 	Train Loss: 1.143 | Train PPL:   3.137 | Train Bleu: 0.893
# 	 Val. Loss: 1.919 |  Val. PPL:   6.815 | Val. Bleu: 0.947 | Accuracy: 0.8776
# Epoch: 492 | Time: 0m 6s
# 	Train Loss: 1.143 | Train PPL:   3.136 | Train Bleu: 0.890
# 	 Val. Loss: 1.978 |  Val. PPL:   7.229 | Val. Bleu: 0.890 | Accuracy: 0.7959
# Epoch: 493 | Time: 0m 6s
# 	Train Loss: 1.136 | Train PPL:   3.114 | Train Bleu: 0.895
# 	 Val. Loss: 1.973 |  Val. PPL:   7.191 | Val. Bleu: 0.882 | Accuracy: 0.7959
# Epoch: 494 | Time: 0m 6s
# 	Train Loss: 1.142 | Train PPL:   3.134 | Train Bleu: 0.895
# 	 Val. Loss: 1.965 |  Val. PPL:   7.134 | Val. Bleu: 0.920 | Accuracy: 0.8571
# Epoch: 495 | Time: 0m 7s
# 	Train Loss: 1.141 | Train PPL:   3.129 | Train Bleu: 0.895
# 	 Val. Loss: 1.962 |  Val. PPL:   7.113 | Val. Bleu: 0.900 | Accuracy: 0.8163
# Epoch: 496 | Time: 0m 7s
# 	Train Loss: 1.141 | Train PPL:   3.129 | Train Bleu: 0.892
# 	 Val. Loss: 1.951 |  Val. PPL:   7.036 | Val. Bleu: 0.904 | Accuracy: 0.8163
# Epoch: 497 | Time: 0m 6s
# 	Train Loss: 1.141 | Train PPL:   3.129 | Train Bleu: 0.897
# 	 Val. Loss: 1.950 |  Val. PPL:   7.030 | Val. Bleu: 0.934 | Accuracy: 0.8776
# Epoch: 498 | Time: 0m 6s
# 	Train Loss: 1.137 | Train PPL:   3.119 | Train Bleu: 0.897
# 	 Val. Loss: 1.965 |  Val. PPL:   7.134 | Val. Bleu: 0.911 | Accuracy: 0.8367
# Epoch: 499 | Time: 0m 6s
# 	Train Loss: 1.137 | Train PPL:   3.117 | Train Bleu: 0.895
# 	 Val. Loss: 1.975 |  Val. PPL:   7.204 | Val. Bleu: 0.893 | Accuracy: 0.8163
# Epoch: 500 | Time: 0m 6s
# 	Train Loss: 1.136 | Train PPL:   3.114 | Train Bleu: 0.900
# 	 Val. Loss: 1.989 |  Val. PPL:   7.306 | Val. Bleu: 0.923 | Accuracy: 0.8571

# %%
# Evaluate
# Load checkpoint
model.load_state_dict(torch.load(model_root / f'{model_name}.pt'))

test_loss, test_bleu, test_acc = evaluate(model, valid_iterator, criterion, TEST_BATCH_SIZE, split='test', islog=True)

print(f'| Test Loss: {test_loss:.3f} | Test PPL: {math.exp(test_loss):7.3f} | Test Bleu: {test_bleu:.3f} | Accuracy: {test_acc:.4f}')

new_test_loss, new_test_bleu, new_test_acc = evaluate(model, test_iterator, criterion, TEST_BATCH_SIZE, split='new_test', islog=True)

print(f'| New Test Loss: {new_test_loss:.3f} | New Test PPL: {math.exp(new_test_loss):7.3f} | New Test Bleu: {new_test_bleu:.3f} | Accuracy: {new_test_acc:.4f}')
# Out:
# | Test Loss: 1.900 | Test PPL:   6.686 | Test Bleu: 0.919 | Accuracy: 0.8776
# | New Test Loss: 2.240 | New Test PPL:   9.394 | New Test Bleu: 0.642 | Accuracy: 0.4490
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
